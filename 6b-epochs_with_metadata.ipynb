# %%
# %matplotlib inline

# %% [markdown]
# # Pandas querying and metadata with Epochs objects
#
# `
# Authors: Chris Holdgraf <choldgraf@gmail.com>
#          Jona Sassenhagen <jona.sassenhagen@gmail.com>
#          Eric Larson <larson.eric.d@gmail.com>
#          Alex Gramfort <alexandre.gramfort@inria.fr>
# `
#
# This notebook demonstrates how to use Epochs with metadata.
# This allows to use [pandas-style string querying](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.query.html) and also to keep
# all metadata aligned with the epochs.
#
# Sometimes you may have a complex trial structure that cannot be easily
# summarized as a set of unique integers. In this case, it may be useful to use
# the ``metadata`` attribute of `mne.Epochs` objects. This must be a
# `pandas.DataFrame` where each row corresponds to an epoch, and each
# column corresponds to a metadata attribute of each epoch. Columns must
# contain either strings, ints, or floats.
#
# In this dataset, subjects were presented with individual words
# on a screen, and the EEG activity in response to each word was recorded.
# We know which word was displayed in each epoch, as well as
# extra information about the word (e.g., word frequency).
#
# See [reference paper](https://hal.archives-ouvertes.fr/hal-01432349/document):
#
#     Dufau, S., Grainger, J., Midgley, KJ., Holcomb, PJ.
#     A thousand words are worth a picture: Snapshots of printed-word processing
#     in an event-related potential megastudy. Psychological Science, 2015
#
# ## Loading the data
#
# First we'll load the data. If metadata exists for an `mne.Epochs`
# fif file, it will automatically be loaded in the ``metadata`` attribute.

# %%
import mne
import numpy as np
import matplotlib.pyplot as plt

# Load the data from the internet
path = mne.datasets.kiloword.data_path() + '/kword_metadata-epo.fif'
epochs = mne.read_epochs(path)
# Out:
# Reading /Users/claire/mne_data/MNE-kiloword-data/kword_metadata-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =    -100.00 ...     920.00 ms
#         0 CTF compensation matrices available
# 960 matching events found
# No baseline correction applied
# Adding metadata with 8 columns
# 0 projection items activated

# %%
# The metadata exists as a Pandas DataFrame
type(epochs.metadata)
# Out:
# pandas.core.frame.DataFrame

# %%
# We have one set of metadata for each epoch:
len(epochs), len(epochs.metadata)
# Out:
# (960, 960)

# %%
# Inspect the content by displaying the first 5 rows
epochs.metadata.head(5)
# Out:
#    WORD  Concreteness  WordFrequency  OrthographicDistance  NumberOfLetters  \
# 0  film          5.45       3.189490                  1.75              4.0
# 1  cent          5.90       3.700704                  1.35              4.0
# 2  shot          4.60       2.858537                  1.20              4.0
# 3  cold          3.70       3.454540                  1.15              4.0
# 4  main          3.00       3.539076                  1.35              4.0
#
#    BigramFrequency  ConsonantVowelProportion  VisualComplexity
# 0           343.25                      0.75         55.783710
# 1           546.75                      0.75         63.141553
# 2           484.75                      0.75         64.600033
# 3          1095.25                      0.75         63.657457
# 4           686.00                      0.50         68.945661

# %%
epochs['loft']
# Out:
# <EpochsFIF  |   1 events (all good), -0.1 - 0.92 sec, baseline off, ~118 kB, data loaded, with metadata,
#  'loft': 1>

# %% [markdown]
# As we have a dataframe one can do standard Pandas manipulations:

# %%
df = epochs.metadata
df[['WORD', 'Concreteness']].head()
# Out:
#    WORD  Concreteness
# 0  film          5.45
# 1  cent          5.90
# 2  shot          4.60
# 3  cold          3.70
# 4  main          3.00

# %%
epochs.metadata[['WORD', 'Concreteness']].head(5)  # take only 2 columns
# Out:
#    WORD  Concreteness
# 0  film          5.45
# 1  cent          5.90
# 2  shot          4.60
# 3  cold          3.70
# 4  main          3.00

# %%
epochs.metadata[['WORD',
                 'Concreteness']].sort_values(
    by="Concreteness", ascending=True).head(5)
# Out:
#          WORD  Concreteness
# 272      fate          1.65
# 241      hope          1.75
# 220  abstract          1.80
# 9        love          1.80
# 626   feeling          1.85

# %%
epochs.metadata.groupby('NumberOfLetters').count()[['WORD']]  # Nb. of word of each length
# Out:
#                  WORD
# NumberOfLetters
# 4.0               192
# 5.0               192
# 6.0               192
# 7.0               192
# 8.0               192

# %%
epochs.metadata['WordFrequency'].plot(kind='hist')  # histogram of word frequencies

# %%
epochs.metadata.groupby('NumberOfLetters').\
    count()[['WORD']].plot(kind='barh')  # Plot nb. of word of each length

# %% [markdown]
# ## Let's use seaborn to make publication ready plots:

# %%
import seaborn as sns

sns.boxplot(x="NumberOfLetters", y="WordFrequency", data=epochs.metadata,
            whis="range", palette="vlag")

# %%
sns.violinplot(x="NumberOfLetters", y="Concreteness",
               data=epochs.metadata,
               palette="vlag")

# %% [markdown]
# ### My first pandas query:

# %%
epochs.metadata.query(
    'Concreteness < 4.5 and NumberOfLetters < 5').head(5)
# Out:
#     WORD  Concreteness  WordFrequency  OrthographicDistance  NumberOfLetters  \
# 3   cold          3.70       3.454540                  1.15              4.0
# 4   main          3.00       3.539076                  1.35              4.0
# 8   idea          1.95       3.688420                  1.90              4.0
# 9   love          1.80       3.607026                  1.15              4.0
# 10  role          3.35       3.322839                  1.10              4.0
#
#     BigramFrequency  ConsonantVowelProportion  VisualComplexity
# 3           1095.25                      0.75         63.657457
# 4            686.00                      0.50         68.945661
# 8            201.75                      0.25         70.667496
# 9            337.25                      0.50         61.394212
# 10           536.25                      0.50         57.463779

# %% [markdown]
# <div class="alert alert-success">
#     <b>Exercise</b>:
#      <ul>
#     <li>How many words have a WordFrequency higher than 4 and a NumberOfLetters of 5</li>
#     <li>What is the distribution of number of letters among the words having a VisualComplexity higher than 65.</li>
#     <li>Represent this distribution with a pie chart.</li>
#     </ul>
# </div>

# %%
# TODO

# %% [markdown]
# # From Epochs slicing to pandas queries
#
# Let's first use standard epochs indexing:

# %%
epochs[0]  # get first epoch
# Out:
# <EpochsFIF  |   1 events (all good), -0.1 - 0.92 sec, baseline off, ~119 kB, data loaded, with metadata,
#  'film': 1>

# %%
epochs[:10]  # get first 10 epoch
# Out:
# <EpochsFIF  |   10 events (all good), -0.1 - 0.92 sec, baseline off, ~641 kB, data loaded, with metadata,
#  'case': 1
#  'cent': 1
#  'cold': 1
#  'film': 1
#  'idea': 1
#  'land': 1
#  'love': 1
#  'main': 1
#  'poet': 1
#  'shot': 1>

# %%
epochs['loft']  # get epoch based on event_id
# Out:
# <EpochsFIF  |   1 events (all good), -0.1 - 0.92 sec, baseline off, ~119 kB, data loaded, with metadata,
#  'loft': 1>

# %% [markdown]
# Now when we have some metadata attached to the epochs one can directly query the epochs
# to select subsets of Epochs. This uses the Pandas :meth:`pandas.DataFrame.query` method under the hood.
# Any valid query string will work. Below we'll make two plots to compare
# between them:

# %%
evoked1 = epochs['Concreteness < 5 and WordFrequency < 2'].average()
evoked2 = epochs['Concreteness > 5 and WordFrequency > 2'].average()

evoked1.plot_joint(times=[0.13, 0.25, 0.4])
evoked2.plot_joint(times=[0.13, 0.25, 0.4]);

# %% [markdown]
# Next we'll choose a subset of words to keep.

# %%
words = ['film', 'cent', 'shot', 'cold', 'main']
epochs['WORD in {}'.format(words)].plot_image()
# Out:
# 5 matching events found
# No baseline correction applied
# Not setting metadata
# 0 projection items activated
# 0 bad epochs dropped
# combining channels using "gfp"
# [<Figure size 432x288 with 3 Axes>]

# %% [markdown]
# ### Advanced
#
# Below we'll show a more involved example that leverages the metadata
# of each epoch. We'll create a new column in our metadata object and use
# it to generate averages for many subsets of trials.

# %%
# Create two new metadata columns
metadata = epochs.metadata
is_concrete = metadata["Concreteness"] > metadata["Concreteness"].median()
metadata["is_concrete"] = np.where(is_concrete, 'Concrete', 'Abstract')
is_long = metadata["NumberOfLetters"] > 5
metadata["is_long"] = np.where(is_long, 'Long', 'Short')
epochs.metadata = metadata
epochs.metadata.head(5)
# Out:
# Replacing existing metadata with 10 columns
#    WORD  Concreteness  WordFrequency  OrthographicDistance  NumberOfLetters  \
# 0  film          5.45       3.189490                  1.75              4.0
# 1  cent          5.90       3.700704                  1.35              4.0
# 2  shot          4.60       2.858537                  1.20              4.0
# 3  cold          3.70       3.454540                  1.15              4.0
# 4  main          3.00       3.539076                  1.35              4.0
#
#    BigramFrequency  ConsonantVowelProportion  VisualComplexity is_concrete  \
# 0           343.25                      0.75         55.783710    Concrete
# 1           546.75                      0.75         63.141553    Concrete
# 2           484.75                      0.75         64.600033    Concrete
# 3          1095.25                      0.75         63.657457    Abstract
# 4           686.00                      0.50         68.945661    Abstract
#
#   is_long
# 0   Short
# 1   Short
# 2   Short
# 3   Short
# 4   Short

# %% [markdown]
# Now we can quickly extract (and plot) subsets of the data. For example, to
# look at words split by word length and concreteness:

# %%
query = "is_long == '{0}' & is_concrete == '{1}'"
evokeds = dict()
for concreteness in ("Concrete", "Abstract"):
    for length in ("Long", "Short"):
        subset = epochs[query.format(length, concreteness)]
        evokeds["/".join((concreteness, length))] = subset.average()

evokeds.keys()
# Out:
# dict_keys(['Concrete/Long', 'Concrete/Short', 'Abstract/Long', 'Abstract/Short'])

# %%
type(evokeds['Concrete/Long'])  # one evoked
# Out:
# mne.evoked.EvokedArray

# %%
evokeds['Concrete/Long'].nave  # obtained by averaging 252 epochs
# Out:
# 252

# %%
evokeds
# Out:
# {'Concrete/Long': <Evoked  |  '0.00 * forest + 0.00 * japanese + 0.00 * vaccine + 0.00 * acreage + 0.00 * electron + 0.00 * hospital + 0.00 * document + 0.00 * machine + 0.00 * stockade + 0.00 * embargo + 0.00 * violin + 0.00 * vortex + 0.00 * corner + 0.00 * station + 0.00 * mother + 0.00 * muffler + 0.00 * pitcher + 0.00 * trench + 0.00 * cavern + 0.00 * material + 0.00 * primate + 0.00 * attorney + 0.00 * stream + 0.00 * camera + 0.00 * congress + 0.00 * engine + 0.00 * resort + 0.00 * walnut + 0.00 * agency + 0.00 * asylum + 0.00 * winter + 0.00 * author + 0.00 * breath + 0.00 * hormone + 0.00 * friction + 0.00 * colossus + 0.00 * safari + 0.00 * belfry + 0.00 * magnolia + 0.00 * sermon + 0.00 * highway + 0.00 * whisper + 0.00 * industry + 0.00 * sleeve + 0.00 * children + 0.00 * duchess + 0.00 * emission + 0.00 * writing + 0.00 * whisky + 0.00 * ghetto + 0.00 * leprosy + 0.00 * ginger + 0.00 * butter + 0.00 * apostle + 0.00 * narrator + 0.00 * pelvis + 0.00 * brother + 0.00 * cylinder + 0.00 * toilet + 0.00 * vanilla + 0.00 * contract + 0.00 * lantern + 0.00 * figure + 0.00 * cancer + 0.00 * pistol + 0.00 * embryo + 0.00 * hybrid + 0.00 * civilian + 0.00 * nebula + 0.00 * female + 0.00 * facility + 0.00 * peroxide + 0.00 * journal + 0.00 * linguist + 0.00 * marine + 0.00 * cavity + 0.00 * canopy + 0.00 * skeleton + 0.00 * officer + 0.00 * sapling + 0.00 * flower + 0.00 * summer + 0.00 * veteran + 0.00 * canister + 0.00 * morning + 0.00 * council + 0.00 * alimony + 0.00 * faucet + 0.00 * tumbler + 0.00 * clarinet + 0.00 * disease + 0.00 * student + 0.00 * zombie + 0.00 * fracture + 0.00 * barbecue + 0.00 * maiden + 0.00 * account + 0.00 * academy + 0.00 * storage + 0.00 * tentacle + 0.00 * algebra + 0.00 * person + 0.00 * luncheon + 0.00 * school + 0.00 * husband + 0.00 * governor + 0.00 * textile + 0.00 * player + 0.00 * cascade + 0.00 * market + 0.00 * audience + 0.00 * faculty + 0.00 * sibling + 0.00 * finger + 0.00 * billiard + 0.00 * anthem + 0.00 * calvary + 0.00 * ribbon + 0.00 * syllable + 0.00 * warranty + 0.00 * morgue + 0.00 * physique + 0.00 * painter + 0.00 * chinese + 0.00 * ceiling + 0.00 * cousin + 0.00 * calendar + 0.00 * signal + 0.00 * clergy + 0.00 * blazer + 0.00 * pencil + 0.00 * compound + 0.00 * library + 0.00 * mineral + 0.00 * railroad + 0.00 * payment + 0.00 * nursery + 0.00 * casino + 0.00 * saddle + 0.00 * weight + 0.00 * assembly + 0.00 * artist + 0.00 * record + 0.00 * bodice + 0.00 * senate + 0.00 * graduate + 0.00 * crater + 0.00 * military + 0.00 * murder + 0.00 * cipher + 0.00 * saloon + 0.00 * elevator + 0.00 * antidote + 0.00 * shelter + 0.00 * hearse + 0.00 * throat + 0.00 * meeting + 0.00 * police + 0.00 * cement + 0.00 * shadow + 0.00 * uniform + 0.00 * carpet + 0.00 * midnight + 0.00 * prison + 0.00 * charter + 0.00 * father + 0.00 * million + 0.00 * aircraft + 0.00 * reading + 0.00 * minstrel + 0.00 * exercise + 0.00 * handle + 0.00 * report + 0.00 * december + 0.00 * disposal + 0.00 * brewery + 0.00 * eclipse + 0.00 * picture + 0.00 * business + 0.00 * senator + 0.00 * surface + 0.00 * lighter + 0.00 * village + 0.00 * pension + 0.00 * director + 0.00 * pumpkin + 0.00 * marble + 0.00 * crystal + 0.00 * squash + 0.00 * crucible + 0.00 * typhoon + 0.00 * corsage + 0.00 * trawler + 0.00 * member + 0.00 * suicide + 0.00 * suspect + 0.00 * election + 0.00 * currency + 0.00 * cavalry + 0.00 * buffoon + 0.00 * dinner + 0.00 * materiel + 0.00 * thicket + 0.00 * horizon + 0.00 * evidence + 0.00 * ballot + 0.00 * cereal + 0.00 * window + 0.00 * sentinel + 0.00 * circle + 0.00 * bungalow + 0.00 * infant + 0.00 * chairman + 0.00 * tissue + 0.00 * limerick + 0.00 * cardinal + 0.00 * thousand + 0.00 * orphan + 0.00 * umpire + 0.00 * battery + 0.00 * monument + 0.00 * estate + 0.00 * cuisine + 0.00 * customer + 0.00 * pattern + 0.00 * distance + 0.00 * traffic + 0.00 * canteen + 0.00 * puberty + 0.00 * employee + 0.00 * couple + 0.00 * blemish + 0.00 * mentor + 0.00 * stiletto + 0.00 * teacher + ...
#  'Concrete/Short': <Evoked  |  '0.00 * loft + 0.00 * fire + 0.00 * uncle + 0.00 * virus + 0.00 * orgy + 0.00 * papa + 0.00 * sign + 0.00 * bench + 0.00 * door + 0.00 * scene + 0.00 * wing + 0.00 * gill + 0.00 * bush + 0.00 * shot + 0.00 * shade + 0.00 * data + 0.00 * briar + 0.00 * hash + 0.00 * spit + 0.00 * clove + 0.00 * shelf + 0.00 * chip + 0.00 * site + 0.00 * floor + 0.00 * case + 0.00 * cent + 0.00 * miner + 0.00 * camp + 0.00 * paper + 0.00 * host + 0.00 * patio + 0.00 * pawn + 0.00 * seat + 0.00 * felon + 0.00 * grail + 0.00 * broil + 0.00 * clan + 0.00 * press + 0.00 * wagon + 0.00 * nest + 0.00 * city + 0.00 * band + 0.00 * grass + 0.00 * crate + 0.00 * grave + 0.00 * item + 0.00 * tomb + 0.00 * money + 0.00 * couch + 0.00 * roof + 0.00 * purse + 0.00 * lady + 0.00 * scale + 0.00 * lock + 0.00 * plant + 0.00 * cross + 0.00 * poet + 0.00 * motor + 0.00 * crowd + 0.00 * rifle + 0.00 * cult + 0.00 * pack + 0.00 * tool + 0.00 * party + 0.00 * boil + 0.00 * child + 0.00 * wheel + 0.00 * cook + 0.00 * lava + 0.00 * piece + 0.00 * ford + 0.00 * tonic + 0.00 * soup + 0.00 * cameo + 0.00 * mouth + 0.00 * book + 0.00 * storm + 0.00 * rain + 0.00 * chair + 0.00 * slat + 0.00 * lasso + 0.00 * snow + 0.00 * slave + 0.00 * beach + 0.00 * skit + 0.00 * snout + 0.00 * dope + 0.00 * spark + 0.00 * board + 0.00 * sprig + 0.00 * bran + 0.00 * pond + 0.00 * girl + 0.00 * plaza + 0.00 * duet + 0.00 * acid + 0.00 * film + 0.00 * drug + 0.00 * clay + 0.00 * trap + 0.00 * movie + 0.00 * bait + 0.00 * pump + 0.00 * woman + 0.00 * rink + 0.00 * poesy + 0.00 * sage + 0.00 * chest + 0.00 * polka + 0.00 * shaft + 0.00 * crust + 0.00 * dome + 0.00 * bone + 0.00 * beer + 0.00 * creek + 0.00 * frame + 0.00 * award + 0.00 * club + 0.00 * earth + 0.00 * half + 0.00 * tango + 0.00 * index + 0.00 * shed + 0.00 * baby + 0.00 * squad + 0.00 * claw + 0.00 * straw + 0.00 * actor + 0.00 * lever + 0.00 * yarn + 0.00 * trail + 0.00 * lymph + 0.00 * stock + 0.00 * staff + 0.00 * shah + 0.00 * pore + 0.00 * mine + 0.00 * drip + 0.00 * milk + 0.00 * pope + 0.00 * suite + 0.00 * cramp + 0.00 * pale + 0.00 * cash + 0.00 * kale + 0.00 * venus + 0.00 * brig + 0.00 * crypt + 0.00 * land + 0.00 * fort + 0.00 * flesh + 0.00 * nasal + 0.00 * whip + 0.00 * cove + 0.00 * king + 0.00 * blade + 0.00 * event + 0.00 * jazz + 0.00 * wind + 0.00 * ranch + 0.00 * giant + 0.00 * inch + 0.00 * poem + 0.00 * waste + 0.00 * blush + 0.00 * knoll + 0.00 * squaw + 0.00 * slice + 0.00 * chief + 0.00 * banjo + 0.00 * water + 0.00 * shore + 0.00 * wall + 0.00 * lute + 0.00 * bank + 0.00 * cleat + 0.00 * thug + 0.00 * hedge + 0.00 * gout + 0.00 * metal + 0.00 * hotel + 0.00 * flail + 0.00 * sheet + 0.00 * aunt + 0.00 * smoke + 0.00 * suit + 0.00 * nose + 0.00 * chin + 0.00 * table + 0.00 * diva + 0.00 * trial + 0.00 * waist + 0.00 * dust + 0.00 * silk + 0.00 * gift + 0.00 * cream + 0.00 * hunk + 0.00 * wire + 0.00 * spout + 0.00 * army + 0.00 * radar + 0.00 * plane + 0.00 * glass + 0.00 * hole + 0.00 * chum + 0.00 * dune + 0.00 * park + 0.00 * pine + 0.00 * radio + 0.00 * stone + 0.00 * cask + 0.00 * blood + 0.00 * wood + 0.00 * golf + 0.00 * shirt + 0.00 * crew + 0.00 * honey + 0.00 * coast + 0.00 * druid + 0.00 * truck + 0.00 * hall + 0.00 * curry + 0.00 * bunk + 0.00 * moon + 0.00 * fence + 0.00 * tree + 0.00 * shell' (average, N=227), [-0.1, 0.92] sec, 29 ch, ~119 kB>,
#  'Abstract/Long': <Evoked  |  '0.00 * spectra + 0.00 * judgment + 0.00 * scuffle + 0.00 * abstract + 0.00 * struggle + 0.00 * poetry + 0.00 * attitude + 0.00 * district + 0.00 * display + 0.00 * purpose + 0.00 * velocity + 0.00 * emphasis + 0.00 * valuable + 0.00 * consort + 0.00 * theory + 0.00 * contrast + 0.00 * turmoil + 0.00 * removal + 0.00 * musical + 0.00 * pacifist + 0.00 * despite + 0.00 * extent + 0.00 * friend + 0.00 * hazard + 0.00 * majesty + 0.00 * heresy + 0.00 * pressure + 0.00 * fluency + 0.00 * future + 0.00 * progress + 0.00 * momentum + 0.00 * inquiry + 0.00 * addition + 0.00 * increase + 0.00 * justice + 0.00 * response + 0.00 * disarray + 0.00 * modicum + 0.00 * motion + 0.00 * standing + 0.00 * feeling + 0.00 * private + 0.00 * advance + 0.00 * location + 0.00 * question + 0.00 * census + 0.00 * trauma + 0.00 * gentile + 0.00 * covert + 0.00 * quality + 0.00 * republic + 0.00 * transit + 0.00 * section + 0.00 * southern + 0.00 * primary + 0.00 * reversal + 0.00 * effort + 0.00 * virtue + 0.00 * credit + 0.00 * meaning + 0.00 * domestic + 0.00 * laughter + 0.00 * drudgery + 0.00 * culture + 0.00 * ovation + 0.00 * answer + 0.00 * modality + 0.00 * conflict + 0.00 * morale + 0.00 * portion + 0.00 * blight + 0.00 * diameter + 0.00 * activity + 0.00 * session + 0.00 * express + 0.00 * creation + 0.00 * fright + 0.00 * infidel + 0.00 * company + 0.00 * cosmetic + 0.00 * default + 0.00 * square + 0.00 * figment + 0.00 * syndrome + 0.00 * nation + 0.00 * average + 0.00 * minute + 0.00 * personal + 0.00 * dynamo + 0.00 * conduct + 0.00 * practice + 0.00 * reason + 0.00 * appeal + 0.00 * benefit + 0.00 * collect + 0.00 * negative + 0.00 * validity + 0.00 * wealth + 0.00 * libido + 0.00 * exemplar + 0.00 * variance + 0.00 * silence + 0.00 * speech + 0.00 * talent + 0.00 * abandon + 0.00 * nature + 0.00 * heretic + 0.00 * slavery + 0.00 * specific + 0.00 * gender + 0.00 * embrace + 0.00 * concern + 0.00 * patience + 0.00 * trouble + 0.00 * neglect + 0.00 * majority + 0.00 * health + 0.00 * victory + 0.00 * absence + 0.00 * ordnance + 0.00 * debate + 0.00 * disaster + 0.00 * service + 0.00 * easement + 0.00 * champion + 0.00 * journey + 0.00 * element + 0.00 * tantrum + 0.00 * division + 0.00 * adherent + 0.00 * quibble + 0.00 * decision + 0.00 * impurity + 0.00 * chivalry + 0.00 * budget + 0.00 * manner + 0.00 * problem + 0.00 * mockery + 0.00 * process + 0.00 * degree + 0.00 * fiction + 0.00 * function + 0.00 * instance + 0.00 * transom + 0.00 * despair + 0.00 * effect + 0.00 * breakage + 0.00 * triumph + 0.00 * volume + 0.00 * design + 0.00 * observe + 0.00 * fruition + 0.00 * danger + 0.00 * freedom + 0.00 * public + 0.00 * discord + 0.00 * recess + 0.00 * ambition + 0.00 * doctrine + 0.00 * deceit + 0.00 * mention + 0.00 * continue + 0.00 * horror + 0.00 * minimum + 0.00 * rising + 0.00 * scenario + 0.00 * cutting + 0.00 * subject + 0.00 * original + 0.00 * fellow + 0.00 * promise + 0.00 * malice + 0.00 * interest + 0.00 * policy + 0.00 * middle + 0.00 * capacity + 0.00 * pleasure + 0.00 * opinion + 0.00 * genius + 0.00 * control + 0.00 * remember + 0.00 * position + 0.00 * strength + 0.00 * advice + 0.00 * prestige + 0.00 * coverage + 0.00 * theology + 0.00 * dominant + 0.00 * nautilus + 0.00 * motive + 0.00 * notion + 0.00 * reverse + 0.00 * common + 0.00 * charge + 0.00 * century + 0.00 * tenure + 0.00 * malady + 0.00 * nothing + 0.00 * concept + 0.00 * complete + 0.00 * oracle + 0.00 * stigma + 0.00 * marriage + 0.00 * phrase + 0.00 * mistake + 0.00 * boredom + 0.00 * groove + 0.00 * duration + 0.00 * infusion + 0.00 * respect + 0.00 * ideology + 0.00 * symbol + 0.00 * crisis + 0.00 * ritual + 0.00 * lecture + 0.00 * bottom + 0.00 * perfect + 0.00 * identity + 0.00 * source + 0.00 * welfare + 0.00 * excuse + 0.00 * current + 0.00 * factor + 0.00 * physical + 0.00 * spirit + 0.00 * exertion + 0.00 * courage + 0.00 * superior + 0.00 * exhibit + 0.00 * change + 0.00 * welcome + 0.00 * special + 0.00 * variabl ...
#  'Abstract/Short': <Evoked  |  '0.01 * save + 0.01 * evil + 0.01 * nerve + 0.01 * mind + 0.01 * crux + 0.01 * cusp + 0.01 * fate + 0.01 * moot + 0.01 * pity + 0.01 * clean + 0.01 * offer + 0.01 * rasp + 0.01 * tone + 0.01 * chaos + 0.01 * joke + 0.01 * lull + 0.01 * reach + 0.01 * wish + 0.01 * shift + 0.01 * limp + 0.01 * main + 0.01 * thing + 0.01 * term + 0.01 * grab + 0.01 * hero + 0.01 * unity + 0.01 * genre + 0.01 * query + 0.01 * curse + 0.01 * whiz + 0.01 * glory + 0.01 * jerk + 0.01 * trip + 0.01 * debt + 0.01 * music + 0.01 * trim + 0.01 * hell + 0.01 * least + 0.01 * safe + 0.01 * hank + 0.01 * blue + 0.01 * deal + 0.01 * wild + 0.01 * ideal + 0.01 * cause + 0.01 * stay + 0.01 * theme + 0.01 * craze + 0.01 * sweet + 0.01 * space + 0.01 * bravo + 0.01 * wise + 0.01 * title + 0.01 * grace + 0.01 * deep + 0.01 * quest + 0.01 * craft + 0.01 * cool + 0.01 * pout + 0.01 * haven + 0.01 * grant + 0.01 * blob + 0.01 * ruin + 0.01 * basis + 0.01 * area + 0.01 * gird + 0.01 * fear + 0.01 * swirl + 0.01 * goal + 0.01 * lack + 0.01 * quirk + 0.01 * hope + 0.01 * heat + 0.01 * self + 0.01 * visit + 0.01 * gist + 0.01 * issue + 0.01 * doubt + 0.01 * mean + 0.01 * filth + 0.01 * trust + 0.01 * story + 0.01 * fable + 0.01 * jiffy + 0.01 * midst + 0.01 * proof + 0.01 * peace + 0.01 * omen + 0.01 * fluke + 0.01 * real + 0.01 * spoof + 0.01 * stray + 0.01 * none + 0.01 * rule + 0.01 * east + 0.01 * duty + 0.01 * love + 0.01 * coax + 0.01 * cycle + 0.01 * month + 0.01 * rift + 0.01 * test + 0.01 * bore + 0.01 * feud + 0.01 * tour + 0.01 * goad + 0.01 * curio + 0.01 * guess + 0.01 * focus + 0.01 * youth + 0.01 * care + 0.01 * team + 0.01 * harm + 0.01 * extra + 0.01 * past + 0.01 * wisp + 0.01 * rogue + 0.01 * voice + 0.01 * abuse + 0.01 * sneak + 0.01 * rough + 0.01 * green + 0.01 * cold + 0.01 * enemy + 0.01 * gaze + 0.01 * force + 0.01 * depth + 0.01 * image + 0.01 * angle + 0.01 * stern + 0.01 * spite + 0.01 * dream + 0.01 * sheer + 0.01 * stuff + 0.01 * moral + 0.01 * rise + 0.01 * phase + 0.01 * dash + 0.01 * buzz + 0.01 * error + 0.01 * array + 0.01 * role + 0.01 * sheen + 0.01 * empty + 0.01 * flop + 0.01 * daily + 0.01 * firm + 0.01 * task + 0.01 * sloop + 0.01 * white + 0.01 * vice + 0.01 * style + 0.01 * idea + 0.01 * truth + 0.01 * wide + 0.01 * wrong + 0.01 * price' (average, N=157), [-0.1, 0.92] sec, 29 ch, ~119 kB>}

# %%
# For the actual visualisation, we store a number of shared parameters.
style_plot = dict(
    colors={"Long": "Crimson", "Short": "Cornflowerblue"},
    linestyles={"Concrete": "-", "Abstract": ":"},
    split_legend=True,
    ci=.68,  # confidence interval
    show_sensors='lower right',
    truncate_yaxis="auto",
    picks=epochs.ch_names.index("Pz"),
)

fig, ax = plt.subplots(figsize=(6, 4))
mne.viz.plot_compare_evokeds(evokeds, axes=ax, **style_plot)
plt.show()

# %% [markdown]
# In order to be able to plot confidence intervals I need the full set of epochs:

# %%
query = "is_long == '{0}' & is_concrete == '{1}'"
evokeds = dict()
for concreteness in ("Concrete", "Abstract"):
    for length in ("Long", "Short"):
        subset = epochs[query.format(length, concreteness)]
        evokeds["/".join((concreteness, length))] = list(subset.iter_evoked())

evokeds.keys()
# Out:
# dict_keys(['Concrete/Long', 'Concrete/Short', 'Abstract/Long', 'Abstract/Short'])

# %%
type(evokeds['Concrete/Long']), type(evokeds['Concrete/Long'][0])  # list of evoked
# Out:
# (list, mne.evoked.EvokedArray)

# %%
fig, ax = plt.subplots(figsize=(6, 4))
mne.viz.plot_compare_evokeds(evokeds, axes=ax, **style_plot)
plt.show()

# %% [markdown]
# Let's now compare words which are 4, 5, 6, 7 or 8 letters long:

# %%
letters = epochs.metadata["NumberOfLetters"].unique().astype(int).astype(str)
letters
# Out:
# array(['4', '5', '6', '7', '8'], dtype='<U21')

# %%
evokeds = dict()
for n_letters in letters:
    evokeds[n_letters] = epochs["NumberOfLetters == " + n_letters].average()

style_plot["colors"] = {n_letters: int(n_letters)
                        for n_letters in letters}
style_plot["cmap"] = ("# of Letters", "viridis_r")
del style_plot['linestyles']

fig, ax = plt.subplots(figsize=(6, 4))
mne.viz.plot_compare_evokeds(evokeds, axes=ax, **style_plot)
plt.show()

# %% [markdown]
# And finally, for the interaction between concreteness and continuous length
# in letters:

# %%
evokeds = dict()
query = "is_concrete == '{0}' & NumberOfLetters == {1}"
for concreteness in ("Concrete", "Abstract"):
    for n_letters in letters:
        subset = epochs[query.format(concreteness, n_letters)]
        evokeds["/".join((concreteness, n_letters))] = subset.average()

style_plot["linestyles"] = {"Concrete": "-", "Abstract": ":"}

fig, ax = plt.subplots(figsize=(6, 4))
mne.viz.plot_compare_evokeds(evokeds, axes=ax, **style_plot)
plt.show()

# %% [markdown]
# <div class="alert alert-info"><h4>Note</h4><p>Creating an mne.Epochs object with metadata is done by passing
#    a pandas.DataFrame to the ``metadata`` kwarg as follows:</p></div>

# %%
data = epochs.get_data()
metadata = epochs.metadata.copy()
epochs_new = mne.EpochsArray(data, epochs.info, metadata=metadata)
# Out:
# 960 matching events found
# No baseline correction applied
# Adding metadata with 10 columns
# 0 projection items activated
# 0 bad epochs dropped
